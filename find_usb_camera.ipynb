# %%
import cv2
from matplotlib import pyplot as plt

# %%
# Find external camera number

for x in range(1, 100):
    cap = cv2.VideoCapture(x, cv2.CAP_DSHOW)
    ret, frame = cap.read()
    if ret == True:
        print(x)
        cap.release
        break
    cap.release
# Out:
# 1

# %%
# Connect to capture device
cap = cv2.VideoCapture(1, cv2.CAP_DSHOW)

# %%
# Get a frame
ret, frame = cap.read()

# %%
ret
# Out:
# True

# %%
frame
# Out:
# array([[[113, 113,  86],
#         [113, 113,  86],
#         [109, 110,  86],
#         ...,
#         [234, 222, 192],
#         [231, 218, 184],
#         [232, 219, 185]],
#
#        [[115, 115,  88],
#         [116, 116,  89],
#         [114, 115,  91],
#         ...,
#         [228, 220, 185],
#         [241, 230, 198],
#         [250, 239, 207]],
#
#        [[116, 117,  88],
#         [116, 117,  88],
#         [111, 115,  90],
#         ...,
#         [226, 221, 182],
#         [231, 225, 190],
#         [232, 226, 191]],
#
#        ...,
#
#        [[  1,   5,   5],
#         [  4,   8,   8],
#         [  3,   5,   4],
#         ...,
#         [  7,   9,  10],
#         [  6,   8,   8],
#         [  6,   8,   8]],
#
#        [[  2,   4,   5],
#         [  3,   5,   6],
#         [  2,   4,   3],
#         ...,
#         [  7,   9,   9],
#         [  4,   6,   7],
#         [  4,   6,   7]],
#
#        [[  3,   5,   6],
#         [  3,   5,   6],
#         [  4,   4,   4],
# ...

# %%
plt.imshow(frame)

# %%
# Releases capture
cap.release
# Out:
# <function VideoCapture.release>
